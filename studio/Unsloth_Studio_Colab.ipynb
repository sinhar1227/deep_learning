# %% [markdown]
# <a href="https://colab.research.google.com/github/sinhar1227/deep_learning/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh --local
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 1509, done.
# remote: Counting objects: 100% (1509/1509), done.
# remote: Compressing objects: 100% (1314/1314), done.
# remote: Total 1509 (delta 201), reused 1021 (delta 171), pack-reused 0 (from 0)
# Receiving objects: 100% (1509/1509), 36.72 MiB | 30.52 MiB/s, done.
# Resolving deltas: 100% (201/201), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  local mode: overlaying /content/unsloth (editable) + unsloth-zoo from git main
#                  upgrading npm...
#   node           v20.19.0 | npm 11.15.0
#                  installing bun...
#                  bun installed (1.3.14)
#                  building frontend...
#                  using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Studio backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [==------------------]  2/14  base packages         deps           overlaying local repo (editable): /content/unsloth
#   deps           overlaying unsloth-zoo from git main
#   deps           [====================] 14/14  ROCm torch (final)
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
#                  installing prebuilt llama.cpp...
#   llama.cpp      prebuilt installed and validated
#                  installed release: unslothai/llama.cpp@b9267
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()
# Out:
# 2026-05-24 08:27:18 [info     ] 🦥 Starting Unsloth Studio...
# 2026-05-24 08:27:18 [info     ]    Loading backend...
# 2026-05-24 08:27:19 [info     ]    Starting server...
# INFO:     Started server process [3232]
# INFO:     Waiting for application startup.
# Hardware detected: CUDA -- Tesla T4
# INFO:     Application startup complete.
# INFO:     Unsloth Studio running on http://34.182.63.68:8888 (To stop: press Ctrl+C -- on macOS, Control+C not Command+C)
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Studio UI to sign in and change it.
# ============================================================
#
# {"timestamp": "2026-05-24T08:27:28.426185Z", "level": "info", "event": "   Server started!"}
# {"timestamp": "2026-05-24T08:27:29.288405Z", "level": "info", "event": "Pre-caching helper GGUF: unsloth/gemma-4-E2B-it-GGUF/gemma-4-E2B-it-UD-Q4_K_XL.gguf"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Unsloth Studio is Ready!
#         </h2>
#         <a href="https://8888-gpu-t4-s-kkb-usw1b2-2eoymon113otl-b.us-west1-2.prod.colab.dev" target="_blank"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 12px 0 0 0; font-size: 14px; font-weight: bold;">
#             If the link doesn't work, you can scroll down to view the UI generated directly in Colab.
#         </p>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace; font-weight: bold;">
#             https://8888-gpu-...
#         </p>
#     </div>

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-05-24T08:27:31.449160Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 22.54}
# {"timestamp": "2026-05-24T08:27:44.395847Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1.63}
# {"timestamp": "2026-05-24T08:27:44.783290Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 3.26}
# {"timestamp": "2026-05-24T08:27:45.813007Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.29}
# {"timestamp": "2026-05-24T08:27:47.295385Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 4.83}
# {"timestamp": "2026-05-24T08:27:54.538780Z", "level": "info", "event": "Helper GGUF cached: 1 file(s)"}
# {"timestamp": "2026-05-24T08:28:58.276509Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 8.09}
# {"timestamp": "2026-05-24T08:29:03.029397Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.99}
# {"timestamp": "2026-05-24T08:29:03.444631Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.41}
# {"timestamp": "2026-05-24T08:29:03.766214Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 4.72}
# {"timestamp": "2026-05-24T08:29:04.575772Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.35}
# {"timestamp": "2026-05-24T08:29:10.599803Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 85.57}
# {"timestamp": "2026-05-24T08:29:11.087575Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/change-password", "status_code": 200, "process_time_ms": 168.6}
# {"timestamp": "2026-05-24T08:29:11.439180Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.92}
# {"timestamp": "2026-05-24T08:29:11.536280Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 3.05}
# {"timestamp": "2026-05-24T08:29:11.804271Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.14}
# {"timestamp": "2026-05-24T08:29:12.124166Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 3.31}
# {"timestamp": "2026-05-24T08:29:12.129652Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 3.21}
# {"timestamp": "2026-05-24T08:29:12.425249Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.41}
# {"timestamp": "2026-05-24T08:29:12.714801Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.46}
# {"timestamp": "2026-05-24T08:29:12.767703Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 2.35}
# {"timestamp": "2026-05-24T08:29:13.004275Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2
-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen2.5-0.5B-unsloth-bnb-4bit', 'unsloth/Qwen3.6-35B-A3B-UD-MLX-4bit', 'unsloth/gemma-4-E2B-it-unsloth-bnb-4bit', 'unsloth/Qwen2.5-7B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3.5-9B', 'unsloth/Qwen3.5-4B', 'unsloth/Qwen3-0.6B-unsloth-bnb-4bit', 'unsloth/Llama-3.2-3B-Instruct', 'unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit', 'unsloth/mistral-7b-instruct-v0.3-bnb-4bit', 'unsloth/Qwen3-8B-unsloth-bnb-4bit', 'unsloth/Qwen2.5-Coder-7B-Instruct-bnb-4bit', 'unsloth/Qwen3.6-35B-A3B-NVFP4', 'unsloth/gemma-3-4b-it', 'unsloth/Qwen2.5-3B-Instruct', 'unsloth/gemma-4-26B-A4B-it', 'unsloth/Qwen3-8B', 'unsloth/gpt-oss-20b-unsloth-bnb-4bit']"}
# {"timestamp": "2026-05-24T08:29:13.565381Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 179.98}
# {"timestamp": "2026-05-24T08:29:13.576325Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-05-24T08:29:13.578412Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-05-24T08:29:13.592198Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/settings", "status_code": 200, "process_time_ms": 22.71}
# {"timestamp": "2026-05-24T08:29:13.593046Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 21.24}
# {"timestamp": "2026-05-24T08:29:13.594157Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 22.27}
# {"timestamp": "2026-05-24T08:29:13.595084Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 23.14}
# {"timestamp": "2026-05-24T08:29:13.597037Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 24.93}
# {"timestamp": "2026-05-24T08:29:13.914058Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 2.25}
# {"timestamp": "2026-05-24T08:29:17.883727Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/update-status", "status_code": 200, "process_time_ms": 123.21}
# {"timestamp": "2026-05-24T08:29:27.896361Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 6.59}
# {"timestamp": "2026-05-24T08:29:27.984023Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 9.83}
# {"timestamp": "2026-05-24T08:29:27.984880Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/scan-folders", "status_code": 200, "process_time_ms": 10.61}
# {"timestamp": "2026-05-24T08:29:27.998629Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 12.61}
# {"timestamp": "2026-05-24T08:29:27.999798Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/recommended-folders", "status_code": 200, "process_time_ms": 13.62}
# {"timestamp": "2026-05-24T08:29:36.066693Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 119.63}
# {"timestamp": "2026-05-24T08:30:03.387450Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 5.07}
# {"timestamp": "2026-05-24T08:30:03.402198Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.55}
# {"timestamp": "2026-05-24T08:30:03.587993Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 9.18}
# {"timestamp": "2026-05-24T08:30:03.598025Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 5.96}
# {"timestamp": "2026-05-24T08:30:03.615335Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-05-24T08:30:03.617568Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-05-24T08:30:03.619110Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 7.1}
# {"timestamp": "2026-05-24T08:30:03.628056Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 4.44}
# {"timestamp": "2026-05-24T08:30:03.650988Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 2.99}
# {"timestamp": "2026-05-24T08:30:03.941075Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 3.07}
# {"timestamp": "2026-05-24T08:30:06.959532Z", "level": "info", "event": "TrainingBackend initialized (subprocess mode)"}
# {"timestamp": "2026-05-24T08:30:07.395346Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 4.46}
# {"timestamp": "2026-05-24T08:30:27.462373Z", "level": "info", "event": "Checking format for dataset: mlabonne/FineTome-100k"}
# {"timestamp": "2026-05-24T08:30:27.607378Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# README.md:   0%|          | 0.00/982 [00:00<?, ?B/s]
# {"timestamp": "2026-05-24T08:30:29.845801Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-05-24T08:30:30.151417Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2694.52}
# {"timestamp": "2026-05-24T08:30:39.077994Z", "level": "info", "event": "Getting model config for: unsloth/gemma-4-E2B-it"}
# {"timestamp": "2026-05-24T08:30:39.089040Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E2B-it.yaml (via mapping)"}
# {"timestamp": "2026-05-24T08:30:39.099511Z", "level": "info", "event": "Model 'unsloth/gemma-4-E2B-it' needs transformers 5.x -- checking vision via subprocess"}
# {"timestamp": "2026-05-24T08:31:01.589829Z", "level": "info", "event": "Vision check (subprocess, transformers 5.x) for 'unsloth/gemma-4-E2B-it': model_type=gemma4, architectures=['Gemma4ForConditionalGeneration'], is_vision=True"}
# {"timestamp": "2026-05-24T08:31:05.955945Z", "level": "info", "event": "Model config result for unsloth/gemma-4-E2B-it: is_vision=True, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=None"}
# {"timestamp": "2026-05-24T08:31:06.040350Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/gemma-4-E2B-it", "status_code": 200, "process_time_ms": 26965.98}
# {"timestamp": "2026-05-24T08:31:23.697017Z", "level": "info", "event": "Checking format for dataset: mlabonne/FineTome-100k"}
# {"timestamp": "2026-05-24T08:31:23.812297Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# {"timestamp": "2026-05-24T08:31:25.054414Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-05-24T08:31:25.320049Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 1625.35}
# {"timestamp": "2026-05-24T08:31:25.650375Z", "level": "info", "event": "Starting training job with model: unsloth/gemma-4-E2B-it"}
# {"timestamp": "2026-05-24T08:31:25.657190Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E2B-it.yaml (via mapping)"}
# {"timestamp": "2026-05-24T08:31:25.658079Z", "level": "info", "event": "ExportOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-05-24T08:31:26.247587Z", "level": "warning", "event": "Could not load config for 'unsloth/gemma-4-E2B-it': The checkpoint you are trying to load has model type `gemma4` but Transformers does not recognize this architecture. This could be because of an issue with the checkpoint, or because your version of Transformers is out of date.\n\nYou can update Transformers with the command `pip install --upgrade transformers`. If this does not work, and the checkpoint is very new, then there may not be a release version that supports this model yet. In this case, you can get the most up-to-date code by installing Transformers from source with the command `pip install git+https://github.com/huggingface/transformers.git`"}
# {"timestamp": "2026-05-24T08:31:26.317143Z", "level": "info", "event": "Training subprocess started (pid=6134)"}
# {"timestamp": "2026-05-24T08:31:26.336385Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 689.95}
# {"timestamp": "2026-05-24T08:31:26.665326Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 13.3}
# {"timestamp": "2026-05-24T08:31:27.238728Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 115.24}
# {"timestamp": "2026-05-24T08:31:27.360803Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 114.0}
# {"timestamp": "2026-05-24T08:31:28.544654Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 6.94}
# {"timestamp": "2026-05-24T08:31:28.552829Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 7.01}
# {"timestamp": "2026-05-24T08:31:28.664465Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 12.92}
# {"timestamp": "2026-05-24T08:31:30.016598Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 3.25}
# {"timestamp": "2026-05-24T08:31:30.034412Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.31}
# {"timestamp": "2026-05-24T08:31:31.546065Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.57}
# {"timestamp": "2026-05-24T08:31:31.555877Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 2.38}
# {"timestamp": "2026-05-24T08:31:31.958508Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 3.24}
# {"timestamp": "2026-05-24T08:31:33.059678Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 12.74}
# {"timestamp": "2026-05-24T08:31:33.063220Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 16.17}
# {"timestamp": "2026-05-24T08:31:34.514217Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.35}
# {"timestamp": "2026-05-24T08:31:34.527554Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 2.92}
# {"timestamp": "2026-05-24T08:31:36.072998Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 5.72}
# {"timestamp": "2026-05-24T08:31:36.081576Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 3.7}
# {"timestamp": "2026-05-24T08:31:36.979723Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 3.44}
# {"timestamp": "2026-05-24T08:31:37.535784Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.98}
# {"timestamp": "2026-05-24T08:31:37.548686Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 4.21}
# {"timestamp": "2026-05-24T08:31:39.054271Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 2.94}
# {"timestamp": "2026-05-24T08:31:39.063685Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.35}
# {"timestamp": "2026-05-24T08:31:40.528243Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 8.63}
# {"timestamp": "2026-05-24T08:31:40.532334Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 12.6}
# {"timestamp": "2026-05-24T08:31:41.971076Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 7.4}
# {"timestamp": "2026-05-24T08:31:42.025633Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 5.0}
# {"timestamp": "2026-05-24T08:31:42.038990Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 8.45}
# {"timestamp": "2026-05-24T08:31:43.583408Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.49}
# {"timestamp": "2026
z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_ZRIy7Rt", "status_code": 200, "process_time_ms": 2.92}
# {"timestamp": "2026-05-24T08:53:16.993655Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/chat/threads/__LOCALID_ZRIy7Rt/messages", "status_code": 200, "process_time_ms": 12.52}
# {"timestamp": "2026-05-24T08:53:17.258069Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_ZRIy7Rt", "status_code": 200, "process_time_ms": 3.02}
# {"timestamp": "2026-05-24T08:53:17.573995Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 12.39}
# {"timestamp": "2026-05-24T08:53:17.575003Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/chat/threads/__LOCALID_ZRIy7Rt/messages/4P7gczi", "status_code": 200, "process_time_ms": 15.24}
# {"timestamp": "2026-05-24T08:53:17.863406Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_ZRIy7Rt", "status_code": 200, "process_time_ms": 2.63}
# {"timestamp": "2026-05-24T08:53:17.868275Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 3.67}
# {"timestamp": "2026-05-24T08:53:18.125919Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/chat/messages:batch", "status_code": 200, "process_time_ms": 3.19}
# {"timestamp": "2026-05-24T08:53:18.153258Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 2.83}
# {"timestamp": "2026-05-24T08:53:18.168124Z", "level": "info", "event": "safetensors: model supports reasoning (enable_thinking)"}
# {"timestamp": "2026-05-24T08:53:18.168958Z", "level": "info", "event": "safetensors: model supports tool calling"}
# {"timestamp": "2026-05-24T08:53:18.170006Z", "level": "info", "event": "safetensors: template advertises tools but uses an emission format the loop cannot parse; suppressing supports_tools"}
# {"timestamp": "2026-05-24T08:53:18.179287Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 24.96}
# {"timestamp": "2026-05-24T08:53:18.459175Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 3.36}
# {"timestamp": "2026-05-24T08:53:18.725220Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/chat/messages:batch", "status_code": 200, "process_time_ms": 5.35}
# {"timestamp": "2026-05-24T08:53:42.902082Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 3.73}
# {"timestamp": "2026-05-24T08:53:42.920566Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 4.16}
# {"timestamp": "2026-05-24T08:53:43.132592Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/cancel", "status_code": 200, "process_time_ms": 13.56}
# {"timestamp": "2026-05-24T08:53:43.134255Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 8.97}
# {"timestamp": "2026-05-24T08:53:43.162035Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 6.05}
# {"timestamp": "2026-05-24T08:53:43.170409Z", "level": "info", "event": "Found 1 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-05-24T08:53:43.173454Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/gemma-4-e2b-it-unsloth-bnb-4bit"}
# {"timestamp": "2026-05-24T08:53:43.178340Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-05-24T08:53:43.182128Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 18.38}
# {"timestamp": "2026-05-24T08:53:43.191246Z", "level": "info", "event": "safetensors: model supports reasoning (enable_thinking)"}
# {"timestamp": "2026-05-24T08:53:43.197083Z", "level": "info", "event": "safetensors: model supports tool calling"}
# {"timestamp": "2026-05-24T08:53:43.198184Z", "level": "info", "event": "safetensors: template advertises tools but uses an emission format the loop cannot parse; suppressing supports_tools"}
# {"timestamp": "2026-05-24T08:53:43.219040Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-05-24T08:53:43.248718Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 61.97}
# {"timestamp": "2026-05-24T08:53:43.267334Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_ZRIy7Rt", "status_code": 200, "process_time_ms": 11.96}
# {"timestamp": "2026-05-24T08:53:44.102224Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_ZRIy7Rt", "status_code": 200, "process_time_ms": 3.07}
# {"timestamp": "2026-05-24T08:53:45.006560Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 3.13}
# {"timestamp": "2026-05-24T08:53:45.206168Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_ZRIy7Rt", "status_code": 200, "process_time_ms": 8.27}
# {"timestamp": "2026-05-24T08:53:45.219977Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_ZRIy7Rt/messages", "status_code": 200, "process_time_ms": 8.45}
# {"timestamp": "2026-05-24T08:53:45.482585Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 11.58}
# {"timestamp": "2026-05-24T08:53:45.546709Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_ZRIy7Rt", "status_code": 200, "process_time_ms": 13.22}
# {"timestamp": "2026-05-24T08:53:45.931125Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/chat/threads/__LOCALID_ZRIy7Rt/messages/8CUiDWj", "status_code": 200, "process_time_ms": 23.66}
# {"timestamp": "2026-05-24T08:53:46.217096Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 20.95}
# {"timestamp": "2026-05-24T08:53:46.238890Z", "level": "info", "event": "Getting model config for: unsloth/gemma-4-E2B-it"}
# {"timestamp": "2026-05-24T08:53:46.253656Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E2B-it.yaml (via mapping)"}
# {"timestamp": "2026-05-24T08:53:46.585406Z", "level": "info", "event": "Model config result for unsloth/gemma-4-E2B-it: is_vision=True, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=None"}
# {"timestamp": "2026-05-24T08:53:46.684451Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/gemma-4-E2B-it", "status_code": 200, "process_time_ms": 450.74}
# {"timestamp": "2026-05-24T08:53:46.697202Z", "level": "info", "event": "Checking format for dataset: mlabonne/FineTome-100k"}
# {"timestamp": "2026-05-24T08:53:46.723886Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_ZRIy7Rt", "status_code": 200, "process_time_ms": 23.84}
# {"timestamp": "2026-05-24T08:53:46.727625Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 27.46}
# {"timestamp": "2026-05-24T08:53:46.825771Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# {"timestamp": "2026-05-24T08:53:46.996315Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 10.78}
# {"timestamp": "2026-05-24T08:53:47.093419Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_ZRIy7Rt", "status_code": 200, "process_time_ms": 13.23}
# {"timestamp": "2026-05-24T08:53:47.096864Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 14.24}
# {"timestamp": "2026-05-24T08:53:47.393707Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_ZRIy7Rt", "status_code": 200, "process_time_ms": 14.56}
# {"timestamp": "2026-05-24T08:53:47.412717Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/chat/messages:batch", "status_code": 200, "process_time_ms": 11.59}
# {"timestamp": "2026-05-24T08:53:47.705938Z", "level": "info", "event": "request_completed", "method": "PATCH", "path": "/api/chat/threads/__LOCALID_ZRIy7Rt", "status_code": 200, "process_time_ms": 21.93}
# {"timestamp": "2026-05-24T08:53:48.311718Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 9.45}
# {"timestamp": "2026-05-24T08:53:48.561450Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-05-24T08:53:48.572400Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2345.97}
# {"timestamp": "2026-05-24T08:53:48.594293Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 4.8}
# {"timestamp": "2026-05-24T08:53:48.887318Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/chat/messages:batch", "status_code": 200, "process_time_ms": 4.26}
# {"timestamp": "2026-05-24T08:53:59.561285Z", "level": "info", "event": "Checking format for dataset: mlabonne/FineTome-100k"}
# {"timestamp": "2026-05-24T08:53:59.659481Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# {"timestamp": "2026-05-24T08:54:00.826153Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-05-24T08:54:01.114780Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 1555.95}

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
